# %% [markdown]
# <a href="https://colab.research.google.com/github/mehfujjamadar868-design/DS.BY.HARRY-PYTHON/blob/main/tuple_and_its_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Packing
person = ("Alice", 25, "Engineer")

# Unpacking
name, age, profession = person
print(name)  # Alice
print(age)   # 25
# Out:
# Alice
# 25

# %%
person = ("mehfuj",22,"ml engineer","amg collage","ich")
name,age,profession,collage,city=person
print(name)
print(age)
print(profession)
print(city)
print(collage)
# Out:
# mehfuj
# 22
# ml engineer
# ich
# amg collage

# %%
L=(1,2,3,4)
k= L[2]
print(len(L))
print(k)
# Out:
# 4
# 3
