# %% [markdown]
# <a href="https://colab.research.google.com/github/mehfujjamadar868-design/DS.BY.HARRY/blob/main/if_else_programes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title if else programes
a = 40

# %%
a=40
if (a<53):
  print("biger number")
else:
  print("smaller number")
# Out:
# biger number

# %%
s=50
if (s<20):
    print("small num")
else:
    print("big num")
# Out:
# big num

# %%
x = 3
if x > 5:
    print("x is greater than 5")
else:
    print("x is not greater than 5")
# Out:
# x is not greater than 5

# %%
x = 3
if x > 10:
    print("x is greater than 10")
elif x > 5:
    print("x is greater than 5 but not more than 10")
elif x == 5:
    print("x is exactly 5")
else:
    print("x is less than 5")
# Out:
# x is less than 5

# %%
age = 18
if age < 18:
    category = "Minor"
elif age < 65:
    category = "Adult"
else:
    category = "Senior Citizen"

print("Category:", category)
# Out:
# Category: Adult

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Score': [85, 40, 75]}
df = pd.DataFrame(data)

df['Result'] = df['Score'].apply(lambda x: 'Pass' if x >= 50 else 'Fail')
print(df)
# Out:
#       Name  Score Result
# 0    Alice     85   Pass
# 1      Bob     40   Fail
# 2  Charlie     75   Pass

# %%
def avg(a,b):
  return (a+b)/2
avg(4,6)
# Out:
# 5.0

# %%
j = 20
